# %% [markdown]
# # **Deteccion de fraudes de tarjetas de credito usando Machile Learning**
#
# El presente proyecto realiza una comparacion de algunos algoritmos de Machine learning aplicados al conjunto de datos de clasficaicon de transacciones fraudulentas de tarjetas de credito.
#
# Debido a la gran cantidad de tecnicas de machine learning y de procesamiento de grandes cantidades de conjunto de datos se hace complicado obtener resultados buenos de clasificacion.
#
# Es por ello que se realizan comparaciones entre un conjunto de datos sin procesar y procesado con distitas tecnicas de machine learning. Ademas se implementa AutoEncoding para ver que tan eficiente es clasificando este tipo de dataset.

# %% [markdown]
# ## Descripcion del Dataset
#
# El conjunto de datos utilizado se puede encontrar [aqui.](https://www.kaggle.com/mlg-ulb/creditcardfraud)
#
# Este dataset tiene 31 variables, de las cuales 28 estan reducidas dimensionalmente *(V1-V28)*, con el fin de transformar datos para proteger las identidades de las personas que han realizado las transacciones con tarjetas de credito.
#
# Este dataset ha nacido capturando datos de transacciones bancarias de uno o mas bancos Europeos. No especifican que bancos o la cantidad de bancos. Aunque, podemos hacer la deduccion que ha sido un solo banco del continente Europeo debido a la estructura del dataset.

# %% [markdown]
# ## Metodologia de Procesado y normalizacion
#
#
#
# *   **Escalar valores:** Se escalan valores que tengan dispariedad en los rangos, mejorando el modelo de clasificacion
# *   **Submuestreo aleatorio:** Se hace este submuestreo debido a la cantidad dispar de datos de una clase con respecto a otra.
# *   **Construccion de un nuevo dataset:** Debido al submuestreo aleatorio nace la necesidad de construir un nuevo dataset con los datos seleccionados. Este conjunto de datos sera el definitivo.
# *   **Particion del conjunto de datos:** Para poder problar los modelos de machine learning se hace una particion del conjunto de datos, escogiendo al azar 75% de los datos para entrenamiento y 25% para las pruebas. Estos fueron los mejores valores que he probado y que mejor resultado de clasificacion dan.
#
#
#
# > Proximamente se analizaran datos atipicos en las variables y se les aplicara una metodologia de manejo de estos, con el fin de mejorar aun mas el modelo de machine learning.

# %% [markdown]
# # **Dependencias**
#
# Las dependencias que se van a manejar en este proyecto son las siguientes
#
#
# *   **Pandas:** Libreria que permite cargar y utilizar datasets y hacer operaciones de manera mas eficiente.
# *   **Sklearn:** Ejecucion de los algoritmos de Preceptron multicapa, KNN, SVM, Random Forest, Regresion Logistica y Clasificador Uno vs el resto.
# *   **TensorFlow - Keras:** Utilizacion para armar el autoenceder
# *   **Numpy:** Manejo de matrices y operaciones de multiplicacion, y concatenacion
# *   **MatPlotLib:** Permite la graficacion de datos
# *   **Seaborn:** Permite la graficacion de datos tabulados de manera mas eficiente que matplotlib
# *   **Tabulate:** Permite imprimir tablas de manera ordenada visualmente.

# %%
from keras.layers import Input, Dense, Dropout, LeakyReLU
from keras.models import Model, Sequential
from keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers

from tensorflow.compat.v1.metrics import accuracy
from tensorflow.keras import backend as K

from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing 
from sklearn.metrics import f1_score, confusion_matrix, classification_report, precision_recall_curve

from sklearn.model_selection import train_test_split
from sklearn import metrics

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import numpy as np
import pandas as pd
import seaborn as sns
import random
import traceback

import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.patches as mpatches

from tabulate import tabulate
import os
import tensorflow as tf
import gc
from concurrent.futures import ProcessPoolExecutor
import functools

import multiprocessing as mp

# %matplotlib inline
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776696121.847684 1433598 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def set_reproducibility(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

# %%
set_reproducibility(42)

# %% [markdown]
# # **Cargar el dataset**
#
# Permite cargar el dataset a la memoria, se utiliza pandas para leerlo. Esta funcion retorna un objeto de la clase DataFrame de pandas.

# %%
def load_dataset():
    dataset = pd.read_csv('creditcard.csv')
    return dataset

dataset = load_dataset()

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# # **Impresion Estadistica**
#
# Para poder analizar el dataset debemos de mirar cuales son las caracteristicas estadisticas de cada variable, y que distribucion tienen, ademas de ver las correlaciones entre los diferentes parametros del conjunto de datos.
#
# Lo anterior se hace con el fin de armar una metodologia mas clara para poder procesar el dataset, y que datos necesitan ser modificados y eliminados.
#
# Para ello, se dibujan los graficos de barras que indican la distribucion del tiempo, del valor monetario de la transaccion y un grafico de distribucion de transacciones fraudulentas y no fraudulentas.

# %%
def graph_statistics(dataset):
    sns.set(font_scale=1.1)
    #Graph Time distribution
    plt.figure(figsize=(10,8))
    plt.title('Distribucion caracteristica tiempo')
    sns.distplot(dataset.Time)
    plt.show()

    #Graph Amount distribution
    plt.figure(figsize=(10,8))
    plt.title('Distribucion caracteristica del valor monetario')
    sns.distplot(dataset.Amount)
    plt.show()

    #Graph fraudulent vs not fraudulents transactions
    counts = dataset.Class.value_counts()
    normal = counts[0]
    fraudulent = counts[1]
    perc_normal = (normal/(normal+fraudulent))*100
    perc_fraudulent = (fraudulent/(normal+fraudulent))*100
    print('Hay {} transacciones no fraudulentas ({:.3f}%) y {} transacciones fraudulentas ({:.3f}%).'.format(normal, perc_normal, fraudulent, perc_fraudulent))
    
    plt.figure(figsize=(12,10))
    sns.barplot(x=counts.index, y=counts)
    plt.title('Cantidad de transacciones fraudulentas Vs. No fraudulentas')
    plt.ylabel('Cantidad')
    plt.xlabel('0:No fraudulenta, 1:Fraudulenta')
    plt.show()

graph_statistics(dataset)
# Out:
# /tmp/ipykernel_1433598/1290413497.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset.Time)
# /tmp/ipykernel_1433598/1290413497.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset.Amount)
# Hay 284315 transacciones no fraudulentas (99.827%) y 492 transacciones fraudulentas (0.173%).

# %% [markdown]
# # Matriz de correlacion

# %%
def correlation_matrix(dataset):
    corrmat = dataset.corr()
    sns.set(font_scale=1.2)
    fig = plt.figure(figsize=(12,9))
    sns.heatmap(corrmat, vmax = .8, square = True)
    plt.show()

correlation_matrix(dataset)

# %% [markdown]
# # **Ejecucion sin preprocesamiento**
#
# Para tener un punto de comparacion y ver lo importante que es el preprocesamiento de un conjunto de datos en machile learning se procede a ejecutar los algoritmos en el dataset sin preprocesamiento.

# %% [markdown]
# ## Modelos de ML a usar
#
# Para este proyecto se utilizaran los siguientes modelos:
#
#
# *   **Perceptron Multicapa:** Es el tipo mas basico de red neuronal. Para este caso de clasificacion funcionara perfectamente. La topologia de este perceptron multicapa consta de 31 neuronas de entrada, 2 capas ocultas, 3 neuronas en la capa y una neurona en la segunda capa. En la capa de salida solamente consta de una neurona. Como funcion de activacion se escoge ReLu para todas las capas. Como optimizador se utiliza el algoritmo Adam con un maximo de iteraciones de 2000 en caso de que el algoritmo no encuentre convergencia. Como semilla para generar los numeros pseudoaleatorios para generar los pesos en la fase de fordwass pass se escoge el numero 1. La constgante alpha para la regularizacion L2 se escoge el numero uno.
# *   **Random Forest:** Es un algoritmo mas avanzado que los arboles de decision. Como parametros solo se le pasa `n_jobs`, el cual activa la ejecucion paralela utilizando todos los nucleos fisicos y logicos disponibles en el procesador.
# *   **KNN:** K vecinos cercanos. Como parametro para escoger los n vecinos sera el nunmero 3.
# *   **Linear SVC:** Debido a que el algoritmod e soporte de maquina vectorial puede demorar en clasificar, se utiliza un modelo derivado de este, mas sencillo y que puede clasificar igual o similar de bien. A esta tecnica le pasamos un clasificador Uno vs el Resto. Como generador de nuemos aleatorios se escoge el numero 0, y con una toleracia de error de `1x10^-5`. Cosmo se hizo en random forest, se activa la ejecucion paralela para utilizar varios hilos del procesador.
# *   **Regresion Logistica:** Como parametros de la regresion logistica se utilizara un optimizador lbfgs con una penalizacion l2. Para genrar numeros pseudoaleatorios se ha escogido la semilla 0 y un maximo de iteraciones de 1000 en caso de que el algoritmo no converga.
# *   **AutoEncoders:** Esta tecnica se explicara posteriormente y veremos los resultados. Es similar a un perceptron multicapa pero se utiliza para reducir la informacion de un conjunto de datos, facilitando la clasificacion de los datos. Tambien se utiliza para procesamiento y analisis de imagenes.

# %%
algs = [['Neural Network', MLPClassifier(hidden_layer_sizes=(16,8,), activation = 'relu'
                    ,solver='adam', alpha = 1, max_iter = 2000, random_state = 1)],
            ['Random Forest', RandomForestClassifier(n_jobs=-1)],
            ['KNN', KNeighborsClassifier(n_neighbors=3)],
            ['Support Machine Vector', OneVsRestClassifier(LinearSVC(random_state=0, tol=1e-05), n_jobs=-1)],
            ['Logistic Regression', LogisticRegression(penalty='l2', solver = 'lbfgs', random_state = 0, max_iter=5000)]]

# %%
columnas = ['Time']
for i in range(1,29):
    col = 'V' + str(i)
    columnas.append(col)
columnas.append('Amount')

y = dataset['Class']
X = pd.DataFrame(dataset, columns=columnas)

# %% [markdown]
# ## Reduccion de dimensionalidad
#
# Esta tecnica de procesamiento se usa cuando se tiene un dataset con demasiadas variables (dimensiones). Para este caso no se reducira la dimensionalidad del conjunto de datos, puesto que hay 28 variables que ya han sido manipuladas con esta tecnica (V1-V28).
#
# Con la reduccion de dimensionalidad se puede graficar los datos mediante un diagrama de dispersion teniendo un dataset con mas de 3 dimensiones.
#
# Teniendo en cuenta lo anterior la reduccion de dismensionalidad para este proyecto no se usara para transformar el conjunto de datos y disminuir las variables del mismo, sino para graficar los datos.

# %%
def reduce_dimensionality(X):
    X = TSNE(n_components=2, random_state=1).fit_transform(X)
    return X

def plot(X, y):
    plt.figure() 
    f, ax = plt.subplots(figsize=(24,16))

    blue_patch = mpatches.Patch(color='#0A0AFF', label='No Fraud')
    red_patch = mpatches.Patch(color='#AF0000', label='Fraud')

    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.tick_params(axis='both', which='minor', labelsize=20)

    ax.scatter(X[:,0], X[:,1], c=(y == 0), cmap='coolwarm', label='No Fraud', linewidths=2)
    ax.scatter(X[:,0], X[:,1], c=(y == 1), cmap='coolwarm', label='Fraud', linewidths=2)
    ax.set_title('t-SNE', fontsize=30)

    ax.grid(True)

    ax.legend(handles=[blue_patch, red_patch])

# %% [markdown]
# Hay varios algoritmos de reduccion de dimensionalidad, se utilizara en este caso t-SNE, implementado en la libreria `SKLearn`.
#
# Hay otros algoritmos de reduccion de dimensionalidad como analisis principal de componentes (PCA) que tambien puede ayudar.

# %%
n = 8000
x_reduced = reduce_dimensionality(X[:n])
plot(x_reduced, y[:n])

# %% [markdown]
# Se puede observar en el grafico anterior que no se ve claramente los 2 clusteres, correspondientes a cada clase (Fraudulento y no fraudulento), por lo que es necesario hacer un procesamiento y reduccion de dimensionalidad.

# %% [markdown]
# ## Particion del dataset
#
# Para poder probar los modelos correctamente se hace un proceso de split o particion basica del dataset, hay otros procesos de aprticion comop la validacion cruzada. Para este proyecto vamos a partir el conjunto de datos utilizando el 75% de los datos para entrenamiento y el 25% restante para pruebas.

# %%
def split_dataset(X, y, test_size = 0.25, random_state = 1):
    X_train, X_test, y_train, y_test=train_test_split(X, y, 
                                                      test_size = test_size, 
                                                      random_state = random_state, 
                                                      shuffle=True)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Dibujar la matrices de confusion
#
# Para porder ver la matriz de confusion se utiliza matplotlib y sea born para graficar de manera visual el resultado de la matriz de confusion.

# %%
def draw_matrix_confusion(yTest, yPred, subplot, name, measures):
    LABELS = ['No Fraude', 'Fraude'] 
    conf_matrix = metrics.confusion_matrix(yTest, yPred) 
    sns.set(font_scale=2)
    ax = plt.subplot(3, 2, subplot)

    sns.heatmap(conf_matrix, xticklabels = LABELS,  
                yticklabels = LABELS, annot = True, fmt ="d"); 
    plt.title(name, fontsize=20, fontweight='bold') 
    plt.ylabel('Clase verdadera', fontsize=20, fontweight='bold') 
    plt.xlabel('Clase predicha\nROC-AUC: {}'.format(measures[-1]), fontsize=20, fontweight='bold') 
    return conf_matrix

# %% [markdown]
# ## Calculo de medidas de desempeño
#
# En este proyecto se calculan las medidas de desempeño para algoritmos de ML de clasificacion. En este proyecto se utilizara la matriz de confusion para calculas las siguientes medidas:
#
# *   Accuracy: Promedio de los que ha clasificado correctamente
# *   Recall
# *   F1-Score
# *   ROC-AUC: Area bajo la curva. Indica verdaderamente si que han bueno ha clasificado.
#
# La desventaja de estas medidas es que no muestran verdaderamente si el modelo esta clasfiicando bien o mal. Este tipo de puntajes de desempeño no muestra un valor real cuando se tienen datos desbalanceados. Es por ello que, acompañado con estas medidas de desempeño se utilizara para evaluar el modelo la matriz de confusion.

# %%
def calculate_measures(y_test, yPred):
    acc = metrics.accuracy_score(y_test, yPred)
    prec = metrics.precision_score(y_test, yPred, average='micro')
    rec = metrics.recall_score(y_test, yPred, average='micro')
    f1 = metrics.f1_score(y_test, yPred, average='weighted', labels=np.unique(yPred))
    roc_auc = metrics.roc_auc_score(y_test, yPred)
    #MCC = metrics.matthews_corrcoef(y_test, yPred)
    return acc, prec, rec, f1, roc_auc

# %% [markdown]
# ## Entrenamiento
#
# Para poder entrenar todos los modelos de ML se utiliza la presente funcion.
#
# Esta consta de un codigo en el cual se extraen los datos que se van a utilizar de entrenamiento y de pruebas, ademas, verfica si el clasificador es un autoencoder (Luego explicare que es), si no es un autoencoder procede a entrenar el modelo y predecir los valores utilizando las funciones `fit` y `predict` de `SkLearn`.

# %%
def plot_training_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history['loss'], label='Error de Entrenamiento (MSE)', linewidth=2)
    plt.plot(history['val_loss'], label='Error de Validación (MSE)', linewidth=2)
    
    plt.title('Curva de Aprendizaje del Autoencoder', fontsize=16)
    plt.ylabel('Mean Squared Error (MSE)', fontsize=12)
    plt.xlabel('Época', fontsize=12)
    plt.legend(loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()

# %%
def make_machine_learning(X, y, classifier):
    # Split de los datos que ya vienen procesados desde train
    X_train, X_test, y_train, y_test = split_dataset(X, y, random_state=1, test_size=0.25)
    history = None

    if isinstance(classifier, Model):
        # Entrenamiento del Autoencoder (solo con normales)
        X_train_normal = X_train[y_train == 0]
        early_stop = EarlyStopping(
            monitor='val_loss',     # Observamos el error en los datos que el modelo no usa para entrenar
            patience=10,            # Si pasan 10 épocas sin que el error baje, se detiene
            mode='min',             # Queremos que el error sea el MÍNIMO posible
            restore_best_weights=True # Recupera los pesos de la mejor época, no de la última
        )

        history = classifier.fit(
            X_train_normal, 
            X_train_normal,
            batch_size=32,
            epochs=200,
            shuffle=True, 
            validation_split=0.2,
            verbose=1,
            callbacks=[early_stop]
        ).history
        
        predictions = classifier.predict(X_test)
        mse = np.mean(np.power(X_test - predictions, 2), axis=1)
        
        # Umbral adaptativo
        train_mse = np.mean(np.power(X_train_normal - classifier.predict(X_train_normal), 2), axis=1)
        #threshold = np.mean(train_mse) + (2 * np.std(train_mse))
        threshold = np.percentile(train_mse, 95)
        yPred = [1 if e > threshold else 0 for e in mse]
    else:
        # Entrenamiento supervisado estándar
        classifier.fit(X_train, y_train)
        yPred = classifier.predict(X_test)

    measures = calculate_measures(y_test, yPred)
    return X_train, X_test, y_train, y_test, measures, yPred, history

# %%
def train(dataset, apply_undersampling=True, apply_normalization=True, apply_pca=False, variance_threshold=0.8):
    fig = plt.figure(figsize =(26, 20))
    fig.suptitle('Comparativa de Modelos: Detección de Fraude', fontsize=30, fontweight='bold')
    performance_measures = []   
    i = 1
    history = None
    for name, classifier in algs:
        tup = []
        
        # --- CONFIGURACIÓN DE ESTRATEGIA POR MODELO ---
        
        # 1. ¿Aplicar Undersampling? 
        # El Autoencoder necesita todos los datos normales (False)
        # Los modelos supervisados necesitan balanceo (True)
        if name == 'AutoEncoding':
            apply_undersampling = False
        # 2. ¿Aplicar Normalización/Escalado?
        # En tu dataset, casi todos los modelos (SVM, KNN, MLP, AE) 
        # requieren datos escalados para converger o calcular distancias.
        
        print(f'\n>>> Configurando {name}:')
        print(f'    - Balanceo (Undersampling): {apply_undersampling}')
        print(f'    - Normalización (Scaling): {apply_normalization}')
            
        # Llamamos al preprocesamiento con las decisiones de esta iteración
        X_proc, y_proc, _ = preprocessing_dataset(
            dataset, 
            random_undersampling=apply_undersampling, 
            apply_scaling=apply_normalization,
            apply_pca=apply_pca,
            variance_threshold=variance_threshold # Pasamos el umbral dinámico
        )
        
        # Enviamos los datos procesados a la maquinaria de entrenamiento
        X_train, X_test, y_train, y_test, measures, yPred, history = make_machine_learning(X_proc, y_proc, classifier)
        
        # Guardamos métricas para la tabla final
        tup.append(name)
        for mea in measures:
            tup.append(mea)
        performance_measures.append(tup)
        
        # Dibujamos la matriz en la posición correspondiente
        print(f'    - Generando matriz de confusión...')
        draw_matrix_confusion(y_test, yPred, i, name, measures)
        i += 1
        
    print('\n' + "="*65)
    print("PROCESO DE EVALUACIÓN FINALIZADO")
    print("="*65)
    
    # Ajuste visual de las gráficas
    fig.tight_layout(pad=3.0)
    plt.show()

    if history is not None:
        #Graficacion
        plot_training_history(history)
    
    # Tabla comparativa profesional
    print(tabulate(performance_measures, 
                   headers=['Method', 'Accuracy', 'Precision', 'Recall', 'f1 Score', 'ROC AUC'], 
                   tablefmt='psql'))

# %%
'''
Metodo para escalar
'''
def scaling(dataset):
    # Usamos RobustScaler para ser inmunes a valores atípicos en Amount y Time
    scaler_time = RobustScaler()
    scaler_amount = RobustScaler()
    
    # Escalamos manteniendo el índice original de Pandas
    scaled_time = pd.Series(
        scaler_time.fit_transform(dataset[['Time']]).flatten(), 
        index=dataset.index
    )
    
    scaled_amount = pd.Series(
        scaler_amount.fit_transform(dataset[['Amount']]).flatten(), 
        index=dataset.index
    )
    
    return scaled_time, scaled_amount

# %%
def preprocessing_dataset(dataset, random_undersampling=True, apply_scaling=True, apply_pca=False, variance_threshold=0.88):
    df_proc = dataset.copy()
    
    # 1. ESCALADO (Indispensable para que PCA no se sesgue por magnitudes)
    if apply_scaling:
        scaled_time, scaled_amount = scaling(df_proc)
        df_proc = pd.concat([df_proc, 
                             scaled_amount.rename('scaled_amount'), 
                             scaled_time.rename('scaled_time')], axis=1)
        df_proc.drop(['Amount', 'Time'], axis=1, inplace=True)

    # 2. PCA DINÁMICO
    if apply_pca:
        X_temp = df_proc.drop(['Class'], axis=1).values
        y_temp = df_proc['Class'].values
        
        # Al pasar un float (0.88), PCA elige el número de componentes 
        # necesarios para llegar a ese porcentaje de información retenida.
        pca = PCA(n_components=variance_threshold)
        X_pca = pca.fit_transform(X_temp)
        
        n_selected = pca.n_components_ # Guardamos cuántos eligió
        
        df_proc = pd.DataFrame(X_pca)
        df_proc['Class'] = y_temp
        print(f"      [PCA AUTO] Reteniendo {variance_threshold*100}% de varianza...")
        print(f"      [PCA AUTO] El sistema seleccionó {n_selected} componentes de los 30 originales.")

    # 3. BALANCEO (Undersampling)
    if random_undersampling:
        dataset_fraud = df_proc[df_proc['Class'] == 1]
        dataset_not_fraud = df_proc[df_proc['Class'] == 0].sample(n=len(dataset_fraud), random_state=1)
        dataset_balanced = pd.concat([dataset_not_fraud, dataset_fraud])
        
        X = dataset_balanced.drop(['Class'], axis=1).values
        y = dataset_balanced['Class'].values
        return X, y, dataset_balanced
    else:
        X = df_proc.drop(['Class'], axis=1).values
        y = df_proc['Class'].values
        return X, y, df_proc

# %%
train(dataset, apply_undersampling=False, apply_normalization=False)
# Out:
# >>> Configurando Neural Network:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): False
#     - Generando matriz de confusión...
#
# >>> Configurando Random Forest:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): False
#     - Generando matriz de confusión...
#
# >>> Configurando KNN:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): False
#     - Generando matriz de confusión...
#
# >>> Configurando Support Machine Vector:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): False
#     - Generando matriz de confusión...
#
# >>> Configurando Logistic Regression:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): False
#     - Generando matriz de confusión...
#
# =================================================================
# PROCESO DE EVALUACIÓN FINALIZADO
# =================================================================
# +------------------------+------------+-------------+----------+------------+-----------+
# | Method                 |   Accuracy |   Precision |   Recall |   f1 Score |   ROC AUC |
# |------------------------+------------+-------------+----------+------------+-----------|
# | Neural Network         |   0.998441 |    0.998441 | 0.998441 |   0.99922  |  0.5      |
# | Random Forest          |   0.999551 |    0.999551 | 0.999551 |   0.999528 |  0.882841 |
# | KNN                    |   0.998483 |    0.998483 | 0.998483 |   0.997791 |  0.518011 |
# | Support Machine Vector |   0.999171 |    0.999171 | 0.999171 |   0.999089 |  0.783706 |
# | Logistic Regression    |   0.999143 |    0.999143 | 0.999143 |   0.999069 |  0.78819  |
# +------------------------+------------+-------------+----------+------------+-----------+

# %% [markdown]
# Como podemos ver en los resultados anteriores, aunque el accuracy haya dado por encima del 99% no significa que los modelos esten clasificando correctamente. Para verificarlo verdaderamente es cuestion de mirar la matriz de confusion.
#
# Teniendo en cuenta lo anterior, todos los modelos les cuesta trabajo clasificar transacciones fraudulentas por la poca cantidad de datos que hay a esta clase por el desbalanceo de datos. Lo anterior produce un fenomeno llamado OverFitting, un sobreentrenamiento de datos disparen por clase, por lo que los modelos no son capaces de clasificar transacciones fraudulentas debido a la gran cantidad de datos de la clase contraria.
#
# Por lo tanto, el modelo de prediccion se puede mejorar bastante aplicando tecnicas de preprocesamiento y normalizacion del conjunto de datos respectivo.

# %% [markdown]
# # **Procesamiento y normalizacion del dataset**

# %% [markdown]
# ## Escalar valores
#
# Debido a que algunos valores no tienen un rango fijo o tienen valores muy altos y muy bajos (Distribucion exponencial) y se tienen pocos rangos de valores. Este caso se cumple para el Monto y para el tiempo.

# %% [markdown]
# ## Random Under-Sampling
#
# Debido un gran desbalanceo de datos de transacciones fraudulentas y no fraudulentas puede provocar que los modelos de prediccion se sobre entrenen y no puedan predecir correctamente las transacciones fraudulentas.
#
# Hay distintas tecnicas para lograr una aprticiond e datos con datos de clases balanceadas. La tecnica que se va a utilizar es la de Random UnderSampling (Muestreo aleatorio), tambien existe la validacion cruzada (K-folds).
#
# La primera tecnica es la mas sencilla de hacer, y consiste en escoger todos los datos de la clase que tenga menos muestras, y de las clases contrarias escoger aleatoriamente datos hasta llegar al numero de muestras de la clase la cual tiene menos datos. Esta tecnica funciona para n cantidad de clases.

# %% [markdown]
# Ejecutamos el preoprocesamiento completo y posteriormente graficamos el numero de datos por cada clase para verificar que el submuestreo aleatorio se ha realizado correctamente.

# %%
dataset = load_dataset()
columnas = ['Time']
for i in range(1,29):
    col = 'V' + str(i)
    columnas.append(col)
columnas.append('Amount')

y = dataset['Class']
X = pd.DataFrame(dataset, columns=columnas)

# %%
X, y, dataset = preprocessing_dataset(dataset)

# %%
correlation_matrix(dataset)

# %%
# Configuración del gráfico
plt.figure(figsize=(10, 8))

# Corrección del error: especificamos x='Class'
sns.countplot(x='Class', data=dataset, hue='Class', palette='viridis', legend=False)

plt.title('Distribución de las clases (Fraude vs. No Fraude)')
plt.xlabel('Clase (0: No fraudulento, 1: Fraudulento)')
plt.ylabel('Cantidad de Transacciones')

plt.show()

# %% [markdown]
# Para ver si hay un resultado claro haciendo procesamiento sobre el conjunto de datos se hace de nuevo uan reduccion de dimensionalidad para poder graficar los datos y ver si hay clusteres definidos.

# %%
x_reduced = reduce_dimensionality(X)
plot(x_reduced, y)

# %% [markdown]
# Como podemos ver hay una clara diferencia con el grafico t-SNE anterior a procesar y normalizar el conjunto de datos, viendose claramente los clusteres mejor marcados.
#
# Con esto bastaria para mejorar el modelo de clasficacion, aunque se pueden eliminar valores atipicos de algunas variables. Este proceso se añadira en el futuro.

# %% [markdown]
# # **Ejecucion con preprocesamiento**
#
# Para ver los resultados ejecutalos los modelos de clasficacion y posteriormente evaluaremos las matrices de confusion y las medidas de desempeño

# %%
dataset = load_dataset()

# %%
algs = [['Neural Network', MLPClassifier(hidden_layer_sizes=(8,4,), activation = 'relu'
                    ,solver='adam', alpha = 1, max_iter = 2000, random_state = 1)],
            ['Random Forest', RandomForestClassifier(n_jobs=-1)],
            ['KNN', KNeighborsClassifier(n_neighbors=3)],
            ['Support Machine Vector', OneVsRestClassifier(LinearSVC(random_state=0, tol=1e-05), n_jobs=-1)],
            ['Logistic Regression', LogisticRegression(penalty='l2', solver = 'lbfgs', random_state = 0, max_iter=1000)]]

# %%
#Entrenar los modelos con el dataset procesado y normalizado
train(dataset, apply_undersampling=True, apply_normalization=True, apply_pca=True, variance_threshold=0.85)
# Out:
# >>> Configurando Neural Network:
#     - Balanceo (Undersampling): True
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
#     - Generando matriz de confusión...
#
# >>> Configurando Random Forest:
#     - Balanceo (Undersampling): True
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
#     - Generando matriz de confusión...
#
# >>> Configurando KNN:
#     - Balanceo (Undersampling): True
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
#     - Generando matriz de confusión...
#
# >>> Configurando Support Machine Vector:
#     - Balanceo (Undersampling): True
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
#     - Generando matriz de confusión...
#
# >>> Configurando Logistic Regression:
#     - Balanceo (Undersampling): True
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
#     - Generando matriz de confusión...
#
# =================================================================
# PROCESO DE EVALUACIÓN FINALIZADO
# =================================================================
# +------------------------+------------+-------------+----------+------------+-----------+
# | Method                 |   Accuracy |   Precision |   Recall |   f1 Score |   ROC AUC |
# |------------------------+------------+-------------+----------+------------+-----------|
# | Neural Network         |   0.939024 |    0.939024 | 0.939024 |   0.93907  |  0.939593 |
# | Random Forest          |   0.926829 |    0.926829 | 0.926829 |   0.926926 |  0.929426 |
# | KNN                    |   0.918699 |    0.918699 | 0.918699 |   0.918807 |  0.921252 |
# | Support Machine Vector |   0.930894 |    0.930894 | 0.930894 |   0.930987 |  0.933214 |
# | Logistic Regression    |   0.930894 |    0.930894 | 0.930894 |   0.930987 |  0.933214 |
# +------------------------+------------+-------------+----------+------------+-----------+

# %% [markdown]
# # **Autoencoders**
#
# Los autoencoders es un tipo de red neuronal el cual se utiliza para reducir informacion de un conjunto de datos o de una imagen. Es un algoritmo semi-supervisado, y por si solo puede llegar a clasificar correctamente y tener buenos resultados.
#
# Esta tecnica tambien se utiliza para reducir informacion innecesaria en una iamgen, para mejorar su procesamiento y recursos computaciones para procesarla y extraer caracteristicas.
#
# ![Topologia de un Autoencoder](https://miro.medium.com/max/1222/1*CMWwGHbuf_T1b7Lon-8HAQ.png)
#
# Para este proyecto se utilizara el autoencoder para reducir informacion innecesaria en el conjunto de datos. El peligro de esto es que llegue a reducir demasiada informacion, provocando perdida y haciendo que el modelo ya no sea tan eficiente.
#
# Para implementarlo se utiliza `tensorflow-keras`. Se puede utilizar tanto la libreria para ejecutarlo en CPU como en GPU.
#
# La topologia constara con 31 capas de entrada, seguida de 14 capas de entrada, seguido de 7 capas, para la parte de decodificacion se utilizara la topologia espejo, con la diferetnecia de que la salida tendra una funcion de activacion reLu.
#
# El optimizador o la resolucion sera adadelta y la funcion de perdida sera MSE (Error cuadratico medio).

# %%
dataset = load_dataset()

# %%
K.clear_session()
gc.collect()
tf.compat.v1.reset_default_graph()
set_reproducibility(42)

# %%
def autoencoding(X, y=None):
    K.clear_session()
    input_dim = 16 # Configurar dependiendo del resultado del PCA
    input_layer = Input(shape=(input_dim,))

    # --- ENCODER ---
    # Capa 1: Reducción inicial + Regularización L2
    encoded = Dense(12, activity_regularizer=regularizers.l2(10e-5))(input_layer)
    encoded = LeakyReLU(alpha=0.01)(encoded) # Activación LeakyReLU
    encoded = Dropout(0.1)(encoded)          # Dropout del 10% para evitar overfitting

    # Capa 2: Cuello de botella (Bottleneck)
    encoded = Dense(8)(encoded)
    encoded = LeakyReLU(alpha=0.01)(encoded)

    # --- DECODER ---
    # Capa 3: Reconstrucción intermedia
    decoded = Dense(12)(encoded)
    decoded = LeakyReLU(alpha=0.01)(decoded)
    decoded = Dropout(0.1)(decoded)

    # Capa de salida: LINEAR para reconstruir el rango del StandardScaler/RobustScaler
    output_layer = Dense(input_dim, activation='linear')(decoded)

    autoencoder = Model(input_layer, output_layer)
    autoencoder.compile(optimizer="adam", loss="mse")

    return autoencoder

# %%
#Agregamos el modelo a la lista de algoritmos de modelos
algs.append(['AutoEncoding', autoencoding(X, y)])
# Out:
# /home/carlos/miniconda3/envs/ia_stable/lib/python3.10/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
#Entrenamos todos los modelos, incluyendo el AutoEncoding
train(dataset, apply_undersampling=False, apply_normalization=True, apply_pca=True, variance_threshold=0.85)
# Out:
# >>> Configurando Neural Network:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
#     - Generando matriz de confusión...
#
# >>> Configurando Random Forest:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
#     - Generando matriz de confusión...
#
# >>> Configurando KNN:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
#     - Generando matriz de confusión...
#
# >>> Configurando Support Machine Vector:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
#     - Generando matriz de confusión...
#
# >>> Configurando Logistic Regression:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
#     - Generando matriz de confusión...
#
# >>> Configurando AutoEncoding:
#     - Balanceo (Undersampling): False
#     - Normalización (Scaling): True
#       [PCA AUTO] Reteniendo 85.0% de varianza...
#       [PCA AUTO] El sistema seleccionó 16 componentes de los 30 originales.
# Epoch 1/200
# I0000 00:00:1776679142.170985 3085196 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_680414__.11
# 5319/5331 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4616
# I0000 00:00:1776679149.208840 3085197 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_680414__.11
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 1.1804 - val_loss: 0.7602
# Epoch 2/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.8884 - val_loss: 0.6405
# Epoch 3/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.8111 - val_loss: 0.5887
# Epoch 4/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.7889 - val_loss: 0.5641
# Epoch 5/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.7751 - val_loss: 0.5476
# Epoch 6/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.7532 - val_loss: 0.5368
# Epoch 7/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.7399 - val_loss: 0.5258
# Epoch 8/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.7340 - val_loss: 0.5198
# Epoch 9/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.7526 - val_loss: 0.5027
# Epoch 10/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.7394 - val_loss: 0.5038
# Epoch 11/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.7027 - val_loss: 0.4921
# Epoch 12/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6920 - val_loss: 0.4742
# Epoch 13/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6833 - val_loss: 0.4726
# Epoch 14/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6828 - val_loss: 0.4669
# Epoch 15/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6705 - val_loss: 0.4680
# Epoch 16/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6681 - val_loss: 0.4583
# Epoch 17/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6683 - val_loss: 0.4655
# Epoch 18/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6596 - val_loss: 0.4605
# Epoch 19/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.7057 - val_loss: 0.4529
# Epoch 20/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6648 - val_loss: 0.4533
# Epoch 21/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6555 - val_loss: 0.4430
# Epoch 22/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6655 - val_loss: 0.4587
# Epoch 23/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6589 - val_loss: 0.4465
# Epoch 24/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6574 - val_loss: 0.4505
# Epoch 25/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6751 - val_loss: 0.4524
# Epoch 26/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6700 - val_loss: 0.4437
# Epoch 27/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6524 - val_loss: 0.4488
# Epoch 28/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6544 - val_loss: 0.4412
# Epoch 29/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6629 - val_loss: 0.4491
# Epoch 30/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6559 - val_loss: 0.4614
# Epoch 31/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6464 - val_loss: 0.4484
# Epoch 32/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6477 - val_loss: 0.4551
# Epoch 33/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6584 - val_loss: 0.4433
# Epoch 34/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6542 - val_loss: 0.4519
# Epoch 35/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 0.6746 - val_loss: 0.4618
# Epoch 36/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6646 - val_loss: 0.4527
# Epoch 37/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6581 - val_loss: 0.4491
# Epoch 38/200
# 5331/5331 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.6432 - val_loss: 0.4488
# 2226/2226 ━━━━━━━━━━━━━━━━━━━━ 2s 785us/step
# 6664/6664 ━━━━━━━━━━━━━━━━━━━━ 5s 744us/step
#     - Generando matriz de confusión...
#
# =================================================================
# PROCESO DE EVALUACIÓN FINALIZADO
# =================================================================
# +------------------------+------------+-------------+----------+------------+-----------+
# | Method                 |   Accuracy |   Precision |   Recall |   f1 Score |   ROC AUC |
# |------------------------+------------+-------------+----------+------------+-----------|
# | Neural Network         |   0.999003 |    0.999003 | 0.999003 |   0.998862 |  0.729652 |
# | Random Forest          |   0.999508 |    0.999508 | 0.999508 |   0.999485 |  0.878322 |
# | KNN                    |   0.999494 |    0.999494 | 0.999494 |   0.999464 |  0.864823 |
# | Support Machine Vector |   0.999171 |    0.999171 | 0.999171 |   0.999089 |  0.783706 |
# | Logistic Regression    |   0.999115 |    0.999115 | 0.999115 |   0.999049 |  0.792673 |
# | AutoEncoding           |   0.949608 |    0.949608 | 0.949608 |   0.972677 |  0.898308 |
# +------------------------+------------+-------------+----------+------------+-----------+

# %% [markdown]
# Si bien el AutoEncoding da buenos resultados esta un poco por debajo de las otras tecnicas de ML de clasificacion. Ajustando la tiopologia y las funciones de activacion se podria llegar a un mejor resultado.

# %% [markdown]
# # Algoritmos geneticos

# %%
K.clear_session()
gc.collect()
tf.compat.v1.reset_default_graph()
set_reproducibility(42)

# %%
def build_autoencoder(config, input_dim):
    from tensorflow.keras.layers import Dense, Dropout, Input
    from tensorflow.keras import Sequential
    from tensorflow.keras.layers import GaussianNoise
    
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(input_dim,)))
    
    # --- LA MEJORA: Gaussian Noise ---
    # Esto "ensucia" la entrada. Solo actúa durante el entrenamiento.
    model.add(GaussianNoise(config.get('noise_level', 0.1)))
    
    # Encoder
    for _ in range(config['hidden_layers']):
        model.add(tf.keras.layers.Dense(config['encoding_dim'] * 2, activation=config['activation']))
        model.add(tf.keras.layers.Dropout(config['dropout_rate']))
        
    # Bottleneck
    model.add(tf.keras.layers.Dense(config['encoding_dim'], activation=config['activation']))
    
    # Decoder
    for _ in range(config['hidden_layers']):
        model.add(tf.keras.layers.Dense(config['encoding_dim'] * 2, activation=config['activation']))
        model.add(tf.keras.layers.Dropout(config['dropout_rate']))
        
    model.add(tf.keras.layers.Dense(input_dim, activation='linear'))
    
    opt = tf.keras.optimizers.Adam(learning_rate=config['learning_rate'])
    model.compile(optimizer=opt, loss='mse')
    return model

# %%
def fitness_function(individuo, X_raw, y_raw, class_weight_dict):
    # Imports internos para procesos paralelos
    import os
    import numpy as np
    from sklearn.metrics import fbeta_score, precision_score, recall_score
    from sklearn.decomposition import PCA
    
    try:
        # 1. Reducción de dimensionalidad
        pca = PCA(n_components=individuo['pca_variance'])
        X_pca = pca.fit_transform(X_raw)
        
        # Split entrenamiento (solo normales)
        #X_normal = X_pca[y_raw == 0]
        #n_val = int(len(X_normal) * 0.2)
        #X_train, X_val = X_normal[:-n_val], X_normal[-n_val:]
        idx_normal = np.where(y_raw == 0)[0]
        idx_fraude = np.where(y_raw == 1)[0]
        np.random.shuffle(idx_normal)
        np.random.shuffle(idx_fraude)
        split_n = int(len(idx_normal) * 0.8)
        split_f = int(len(idx_fraude) * 0.8)
        train_idx = np.concatenate([idx_normal[:split_n], idx_fraude[:split_f]])
        val_idx = np.concatenate([idx_normal[split_n:], idx_fraude[split_f:]])
        
        X_train, y_train = X_pca[train_idx], y_raw[train_idx]
        X_val, y_val = X_pca[val_idx], y_raw[val_idx]
        
        # 2. Construcción y Entrenamiento
        model = build_autoencoder(individuo, X_pca.shape[1])
        historial = model.fit(
            X_train, X_train, 
            epochs=individuo['epochs'], 
            batch_size=individuo['batch_size'], 
            validation_data=(X_val, X_val),
            class_weight=class_weight_dict,
            verbose=0
        )
        
        # 3. Inferencia y Umbral
        recons = model.predict(X_pca, verbose=0)
        mse = np.mean(np.power(X_pca - recons, 2), axis=1)
        
        # Calculamos el umbral sobre el set de validación (que el modelo no ha "visto")
        recons_val = model.predict(X_val, verbose=0)
        mse_val = np.mean(np.power(X_val - recons_val, 2), axis=1)
        thresh = np.percentile(mse_val, individuo['threshold_percentile'])
        
        y_pred = (mse > thresh).astype(int)
        
        # 4. Cálculo de Métricas avanzadas
        # Usamos F2-Score: Prioriza Recall sobre Precision
        f2 = fbeta_score(y_raw, y_pred, beta=3, zero_division=0)
        prec = precision_score(y_raw, y_pred, zero_division=0)
        rec = recall_score(y_raw, y_pred, zero_division=0)

        # --- LÓGICA DE FITNESS OPTIMIZADA ---
        # Queremos un Recall alto, pero si la precisión cae por debajo de un umbral,
        # penalizamos el score para evitar modelos inútiles en producción.
        target_precision = 0.15 
        penalty = 1.0
        if prec < target_precision:
            # Penalización suave: reduce el score proporcionalmente a la caída de precisión
            penalty = (prec / target_precision) ** 2 

        score_real = f2 * penalty
        
        if score_real > 0:
            return float(score_real)
        else:
            # Recompensa por aprendizaje (mejora de pérdida)
            initial_loss = historial.history['loss'][0]
            final_loss = historial.history['loss'][-1]
            improvement = (initial_loss - final_loss) / (initial_loss + 1e-9)
            return float(0.01 + (improvement * 0.01))

    except Exception as e:
        # Importante para debug en multiprocessing
        print(f'Error en Fitness: {e}')
        return 0.00000001

# %%
def crear_poblacion(n, espacio):
    """Genera una poblacion inicial de `n` individuos aleatorios.

    Cada individuo es un dict con un valor tomado al azar de cada gen
    definido en `espacio`.
    """
    poblacion = []
    for _ in range(n):
        individuo = {gen: random.choice(valores) for gen, valores in espacio.items()}
        poblacion.append(individuo)
    return poblacion


def seleccion_torneo(poblacion, scores, k=3):
    """Seleccion por torneo de tamano `k`.

    Se escogen `k` individuos al azar de la poblacion y se retorna el que
    tenga mayor fitness. Es un operador simple y efectivo frente a la ruleta.
    """
    indices = random.sample(range(len(poblacion)), k)
    mejor_idx = max(indices, key=lambda i: scores[i])
    return poblacion[mejor_idx]


def crossover(padre_a, padre_b):
    hijo = {}
    for gen in padre_a.keys():
        # El hijo hereda el dropout_rate de uno de los dos padres aleatoriamente
        hijo[gen] = padre_a[gen] if random.random() > 0.5 else padre_b[gen]
    return hijo

def mutate(individuo, search_space, prob_mutacion=0.2):
    """
    Mutación por reemplazo: si un gen muta, selecciona un nuevo valor 
    válido desde el espacio de búsqueda original.
    """
    # Creamos una copia para no modificar el original por referencia
    mutante = individuo.copy()
    
    for gen in mutante.keys():
        if random.random() < prob_mutacion:
            # Seleccionamos un valor nuevo de la lista correspondiente en el search_space
            nuevo_valor = random.choice(search_space[gen])
            
            # Opcional: Asegurarnos de que el valor realmente cambie
            while len(search_space[gen]) > 1 and nuevo_valor == mutante[gen]:
                nuevo_valor = random.choice(search_space[gen])
                
            mutante[gen] = nuevo_valor
            
    return mutante
    
def preprocessing_dynamic(dataset, variance_threshold):
    df_proc = dataset.copy()
    
    # Escalado Robusto (Indispensable)
    scaler = RobustScaler()
    df_proc[['Time', 'Amount']] = scaler.fit_transform(df_proc[['Time', 'Amount']])
    
    X_raw = df_proc.drop(['Class'], axis=1).values
    y = df_proc['Class'].values
    
    # PCA con el umbral que el individuo "heredó"
    pca = PCA(n_components=variance_threshold)
    X_pca = pca.fit_transform(X_raw)
    
    return X_pca, y

# %%
def crear_poblacion(n, espacio):
    """Genera una poblacion inicial de `n` individuos aleatorios.

    Cada individuo es un dict con un valor tomado al azar de cada gen
    definido en `espacio`.
    """
    poblacion = []
    for _ in range(n):
        individuo = {gen: random.choice(valores) for gen, valores in espacio.items()}
        poblacion.append(individuo)
    return poblacion


def seleccion_torneo(poblacion, scores, k=3):
    """Seleccion por torneo de tamano `k`.

    Se escogen `k` individuos al azar de la poblacion y se retorna el que
    tenga mayor fitness. Es un operador simple y efectivo frente a la ruleta.
    """
    indices = random.sample(range(len(poblacion)), k)
    mejor_idx = max(indices, key=lambda i: scores[i])
    return poblacion[mejor_idx]


def cruce(padre1, padre2):
    """Cruce uniforme: cada gen se toma de `padre1` o `padre2` con p=0.5.

    Retorna un unico hijo (nuevo dict), sin modificar los padres.
    """
    hijo = {}
    for gen in padre1.keys():
        hijo[gen] = padre1[gen] if random.random() < 0.5 else padre2[gen]
    return hijo


def mutacion(individuo, espacio, tasa=0.15):
    """Mutacion gen a gen con probabilidad `tasa`.

    Retorna una copia del individuo en la que cada gen, independientemente,
    puede haber sido reemplazado por un valor aleatorio del espacio.
    """
    mutado = dict(individuo)
    for gen, valores in espacio.items():
        if random.random() < tasa:
            mutado[gen] = random.choice(valores)
    return mutado
    
def evaluar_individuo(individuo, X, y):
    # 1. Configurar crecimiento de memoria ANTES de cualquier operación de TF
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)
            
    # 2. Ahora sí, importar y ejecutar el fitness
    return fitness(individuo, X, y)

# %%
def run_genetic_optimization(df_raw, generations=5, pop_size=20):
    from sklearn.utils.class_weight import compute_class_weight
    import numpy as np
    # Escalado GLOBAL (Mejor para Redes Neuronales)
    scaler = RobustScaler()
    # Escalamos todo el X, no solo dos columnas
    X_raw = scaler.fit_transform(df_raw.drop('Class', axis=1).values)
    y_raw = df_raw['Class'].values

    weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_raw),
        y=y_raw
    )
    
    # Creamos el diccionario para Keras
    # Esto le dará un peso gigante a la clase 1 (fraude)
    class_weight_dict = {0: 1, 1: 50}
    
    print(f"Pesos asignados: {class_weight_dict}")

    search_space = {
        'encoding_dim': [8, 12, 16, 24],
        'noise_level': [0.05, 0.1, 0.15],
        'hidden_layers': [1, 2, 3],
        'activation': ['relu', 'elu'],
        'optimizer': ['adam', 'sgd'],
        'batch_size': [256, 512, 1024],
        'epochs': [50, 100, 200], # Reducido para que la búsqueda sea ágil
        'learning_rate': [0.001, 0.0005, 0.0001],
        'pca_variance': [0.8, 0.85, 0.90],
        'threshold_percentile': [98.0, 99.0, 99.5, 99.9],
        'dropout_rate': [0.1, 0.2, 0.3]
    }

    poblacion = [{k: random.choice(v) for k, v in search_space.items()} for _ in range(pop_size)]    
    history = []
    
    for gen in range(generations):
        print(f"🧬 Generación {gen+1} en marcha...")
        with ProcessPoolExecutor(max_workers=8, mp_context=mp.get_context('fork')) as ex:
            futures = [ex.submit(fitness_function, ind, X_raw, y_raw, class_weight_dict) for ind in poblacion]
            scores = [f.result() for f in futures]
        
        # Selección y ordenamiento
        idx = np.argsort(scores)[::-1]
        poblacion = [poblacion[i] for i in idx]
        mejor_score = scores[idx[0]]
        mejor_params = poblacion[0].copy() # Copia para evitar referencias
        
        print(f"🏆 Mejor Score Gen {gen+1}: {mejor_score}")
        
        # --- GUARDAR EN EL HISTORIAL ---
        history.append({
            'generation': gen + 1,
            'best_score': mejor_score,
            'params': mejor_params
        })
        
        # Evolución (Elitismo y reproducción)
        nueva_pob = poblacion[:2]
        while len(nueva_pob) < pop_size:
            hijo = crossover(random.choice(poblacion[:15]), random.choice(poblacion[:15]))
            nueva_pob.append(mutate(hijo, search_space, prob_mutacion=0.3))
        poblacion = nueva_pob

    # Retornamos el ganador y el historial completo
    return poblacion[0], scores[idx[0]], history

# %%
# 1) Ejecutar el algoritmo genetico
dataset = load_dataset()
mejor_config, mejor_score, history_ag = run_genetic_optimization(dataset, generations=10, pop_size=40)
# Out:
# Pesos asignados: {0: 1, 1: 50}
# 🧬 Generación 1 en marcha...
# W0000 00:00:1776703141.219472 1433598 gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was false.
# I0000 00:00:1776703141.219950 1433598 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7496 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# W0000 00:00:1776703141.396994 1433598 gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was false.
# I0000 00:00:1776703141.397298 1433598 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 
dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1350115__.17
# 🏆 Mejor Score Gen 10: 0.49530761209593327

# %%
mejor_config
# Out:
# {'encoding_dim': 12,
#  'noise_level': 0.1,
#  'hidden_layers': 1,
#  'activation': 'relu',
#  'optimizer': 'sgd',
#  'batch_size': 512,
#  'epochs': 200,
#  'learning_rate': 0.0001,
#  'pca_variance': 0.9,
#  'threshold_percentile': 99.5,
#  'dropout_rate': 0.1}

# %%
history_ag[8]
# Out:
# {'generation': 9,
#  'best_score': 0.5277777777777778,
#  'params': {'encoding_dim': 16,
#   'noise_level': 0.15,
#   'hidden_layers': 2,
#   'activation': 'relu',
#   'optimizer': 'adam',
#   'batch_size': 1024,
#   'epochs': 50,
#   'learning_rate': 0.0005,
#   'pca_variance': 0.9,
#   'threshold_percentile': 99.5,
#   'dropout_rate': 0.1}}

# %%
mejor_config = history_ag[8]

# %%
import json
with open('mejor_config_autoencoder.json', 'w') as f:
    json.dump(mejor_config, f)

# %%
scaler = RobustScaler()
# Escalamos todo el X, no solo dos columnas
X_raw = scaler.fit_transform(dataset.drop('Class', axis=1).values)
y_raw = dataset['Class'].values

# %%
pca = PCA(n_components=mejor_config['params']['pca_variance'])
X_pca = pca.fit_transform(X_raw)

# %%
# 2) Entrenar y evaluar el autoencoder optimizado con la mejor configuracion
#    IMPORTANTE: entrenar solo con clase 0 (no fraude) para que coincida con fitness()
class_weight_dict = {0: 1, 1: 50}

idx_normal = np.where(y_raw == 0)[0]
idx_fraude = np.where(y_raw == 1)[0]
np.random.shuffle(idx_normal)
np.random.shuffle(idx_fraude)
split_n = int(len(idx_normal) * 0.8)
split_f = int(len(idx_fraude) * 0.8)
train_idx = np.concatenate([idx_normal[:split_n], idx_fraude[:split_f]])
val_idx = np.concatenate([idx_normal[split_n:], idx_fraude[split_f:]])
        
X_train, y_train = X_pca[train_idx], y_raw[train_idx]
X_val, y_val = X_pca[val_idx], y_raw[val_idx]

ae_opt = build_autoencoder(mejor_config['params'], X_train.shape[1])
callbacks_final = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', 
        patience=15, # Un poco más de paciencia para el final
        restore_best_weights=True
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath='autoencoder_fraude_final.keras', # NOMBRE ÚNICO Y DEFINITIVO
        monitor='val_loss', 
        save_best_only=True
    )
]

history = ae_opt.fit(
    X_train, X_train,
    batch_size=mejor_config['params']['batch_size'],
    epochs=500,
    validation_data=(X_val, X_val),
    callbacks=callbacks_final,
    verbose=1,
    class_weight=class_weight_dict,
    shuffle=True
).history
# Out:
# Epoch 1/500
# I0000 00:00:1776715629.777344 4170753 service.cc:153] XLA service 0x7f36c8034db0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776715629.777365 4170753 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce GTX 1080, Compute Capability 6.1 (Driver: 13.0.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.10.1)
# I0000 00:00:1776715629.805005 4170753 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1776715630.005070 4170753 cuda_dnn.cc:461] Loaded cuDNN version 91001
# I0000 00:00:1776715630.099225 4170753 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_2460__.13
# 115/223 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14.9614
# I0000 00:00:1776715631.913108 4170753 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 191/223 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 14.7786
# I0000 00:00:1776715632.493950 4170754 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_2460__.13
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 14.0071 - val_loss: 2.4242
# Epoch 2/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8765 - val_loss: 1.9728
# Epoch 3/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7143 - val_loss: 1.6636
# Epoch 4/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6919 - val_loss: 1.4585
# Epoch 5/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1533 - val_loss: 1.3246
# Epoch 6/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8718 - val_loss: 1.2626
# Epoch 7/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8288 - val_loss: 1.1849
# Epoch 8/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4654 - val_loss: 1.2006
# Epoch 9/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3867 - val_loss: 1.1227
# Epoch 10/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2215 - val_loss: 1.0546
# Epoch 11/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9439 - val_loss: 1.0023
# Epoch 12/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8134 - val_loss: 0.9838
# Epoch 13/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7694 - val_loss: 0.9565
# Epoch 14/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7637 - val_loss: 0.9671
# Epoch 15/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7824 - val_loss: 0.9199
# Epoch 16/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6064 - val_loss: 0.9260
# Epoch 17/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5557 - val_loss: 0.9013
# Epoch 18/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4938 - val_loss: 0.8869
# Epoch 19/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6921 - val_loss: 0.9168
# Epoch 20/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4670 - val_loss: 0.8686
# Epoch 21/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3446 - val_loss: 0.8834
# Epoch 22/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3620 - val_loss: 0.8782
# Epoch 23/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3996 - val_loss: 0.8621
# Epoch 24/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3204 - val_loss: 0.8527
# Epoch 25/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3141 - val_loss: 0.8404
# Epoch 26/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3793 - val_loss: 0.8331
# Epoch 27/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2198 - val_loss: 0.8186
# Epoch 28/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1849 - val_loss: 0.8122
# Epoch 29/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2407 - val_loss: 0.8230
# Epoch 30/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1844 - val_loss: 0.8180
# Epoch 31/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2318 - val_loss: 0.7911
# Epoch 32/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2328 - val_loss: 0.7962
# Epoch 33/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1754 - val_loss: 0.7955
# Epoch 34/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1323 - val_loss: 0.7941
# Epoch 35/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1881 - val_loss: 0.7949
# Epoch 36/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1301 - val_loss: 0.7826
# Epoch 37/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1564 - val_loss: 0.7542
# Epoch 38/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2357 - val_loss: 0.7557
# Epoch 39/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0604 - val_loss: 0.7564
# Epoch 40/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0644 - val_loss: 0.7437
# Epoch 41/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0358 - val_loss: 0.7481
# Epoch 42/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9806 - val_loss: 0.7437
# Epoch 43/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0747 - val_loss: 0.7370
# Epoch 44/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9796 - val_loss: 0.7346
# Epoch 45/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0660 - val_loss: 0.7149
# Epoch 46/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9902 - val_loss: 0.7137
# Epoch 47/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9895 - val_loss: 0.7029
# Epoch 48/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9220 - val_loss: 0.6891
# Epoch 49/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9878 - val_loss: 0.7157
# Epoch 50/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8495 - val_loss: 0.7116
# Epoch 51/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7809 - val_loss: 0.7073
# Epoch 52/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9665 - val_loss: 0.7072
# Epoch 53/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9002 - val_loss: 0.6893
# Epoch 54/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9258 - val_loss: 0.6811
# Epoch 55/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9820 - val_loss: 0.6748
# Epoch 56/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9265 - val_loss: 0.6732
# Epoch 57/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8668 - val_loss: 0.6885
# Epoch 58/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9418 - val_loss: 0.6547
# Epoch 59/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8150 - val_loss: 0.6712
# Epoch 60/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8394 - val_loss: 0.6323
# Epoch 61/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7795 - val_loss: 0.6662
# Epoch 62/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8856 - val_loss: 0.6637
# Epoch 63/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8662 - val_loss: 0.6488
# Epoch 64/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9103 - val_loss: 0.6444
# Epoch 65/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7816 - val_loss: 0.6726
# Epoch 66/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9663 - val_loss: 0.6657
# Epoch 67/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8065 - val_loss: 0.6505
# Epoch 68/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8214 - val_loss: 0.6505
# Epoch 69/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8910 - val_loss: 0.6467
# Epoch 70/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7804 - val_loss: 0.6378
# Epoch 71/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8916 - val_loss: 0.6514
# Epoch 72/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8041 - val_loss: 0.6374
# Epoch 73/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8717 - val_loss: 0.6249
# Epoch 74/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7033 - val_loss: 0.6269
# Epoch 75/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7156 - val_loss: 0.6290
# Epoch 76/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9490 - val_loss: 0.6372
# Epoch 77/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7796 - val_loss: 0.6315
# Epoch 78/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8013 - val_loss: 0.6230
# Epoch 79/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7060 - val_loss: 0.6277
# Epoch 80/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7699 - val_loss: 0.6188
# Epoch 81/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7391 - val_loss: 0.6149
# Epoch 82/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9378 - val_loss: 0.6354
# Epoch 83/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7650 - val_loss: 0.6340
# Epoch 84/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7249 - val_loss: 0.6088
# Epoch 85/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7843 - val_loss: 0.6224
# Epoch 86/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7012 - val_loss: 0.6273
# Epoch 87/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6335 - val_loss: 0.6369
# Epoch 88/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7014 - val_loss: 0.6209
# Epoch 89/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7945 - val_loss: 0.6121
# Epoch 90/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8077 - val_loss: 0.6196
# Epoch 91/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6665 - val_loss: 0.6083
# Epoch 92/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7400 - val_loss: 0.5964
# Epoch 93/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7617 - val_loss: 0.6000
# Epoch 94/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6862 - val_loss: 0.5935
# Epoch 95/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8314 - val_loss: 0.6122
# Epoch 96/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6746 - val_loss: 0.5908
# Epoch 97/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7080 - val_loss: 0.5866
# Epoch 98/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7292 - val_loss: 0.6053
# Epoch 99/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6765 - val_loss: 0.6104
# Epoch 100/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8334 - val_loss: 0.6103
# Epoch 101/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5877 - val_loss: 0.6161
# Epoch 102/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6239 - val_loss: 0.6113
# Epoch 103/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6798 - val_loss: 0.5955
# Epoch 104/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6328 - val_loss: 0.5847
# Epoch 105/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7122 - val_loss: 0.5825
# Epoch 106/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6883 - val_loss: 0.5985
# Epoch 107/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6791 - val_loss: 0.6172
# Epoch 108/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6485 - val_loss: 0.5890
# Epoch 109/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6536 - val_loss: 0.6037
# Epoch 110/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6884 - val_loss: 0.5796
# Epoch 111/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5661 - val_loss: 0.5904
# Epoch 112/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7357 - val_loss: 0.6511
# Epoch 113/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6987 - val_loss: 0.5850
# Epoch 114/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6830 - val_loss: 0.6259
# Epoch 115/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6248 - val_loss: 0.5767
# Epoch 116/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6232 - val_loss: 0.5991
# Epoch 117/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7072 - val_loss: 0.5973
# Epoch 118/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6495 - val_loss: 0.6059
# Epoch 119/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6159 - val_loss: 0.5977
# Epoch 120/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6606 - val_loss: 0.5672
# Epoch 121/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6744 - val_loss: 0.5826
# Epoch 122/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5639 - val_loss: 0.5835
# Epoch 123/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5270 - val_loss: 0.6098
# Epoch 124/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5539 - val_loss: 0.6237
# Epoch 125/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6481 - val_loss: 0.5650
# Epoch 126/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5642 - val_loss: 0.5869
# Epoch 127/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5439 - val_loss: 0.5836
# Epoch 128/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5666 - val_loss: 0.5767
# Epoch 129/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6222 - val_loss: 0.5816
# Epoch 130/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5455 - val_loss: 0.6021
# Epoch 131/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5915 - val_loss: 0.5825
# Epoch 132/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6349 - val_loss: 0.5987
# Epoch 133/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6595 - val_loss: 0.5921
# Epoch 134/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7710 - val_loss: 0.5958
# Epoch 135/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5489 - val_loss: 0.5764
# Epoch 136/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6187 - val_loss: 0.5790
# Epoch 137/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6449 - val_loss: 0.5897
# Epoch 138/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5942 - val_loss: 0.5934
# Epoch 139/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5740 - val_loss: 0.5793
# Epoch 140/500
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5908 - val_loss: 0.5911

# %%
from sklearn.metrics import confusion_matrix, classification_report, fbeta_score
def evaluate_set(X, y, model, threshold, set_name="Dataset"):
    # 1. Inferencia
    recons = model.predict(X, verbose=0)
    mse = np.mean(np.power(X - recons, 2), axis=1)
    
    # 2. Predicción binaria
    y_pred = (mse > threshold).astype(int)
    
    # 3. Métricas
    tn, fp, fn, tp = confusion_matrix(y, y_pred).ravel()
    
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f2 = fbeta_score(y, y_pred, beta=2, zero_division=0)
    especificidad = tn / (tn + fp) if (tn + fp) > 0 else 0
    
    print(f"\n=== EVALUACIÓN: {set_name} ===")
    print(f"Umbral utilizado: {threshold:.4f}")
    print(f"Matriz de Confusión:\n{confusion_matrix(y, y_pred)}")
    print(f"\nReporte de Clasificación:\n{classification_report(y, y_pred)}")
    
    print(f"--- Medidas de Desempeño ---")
    print(f"Precisión:      {precision:.4f}")
    print(f"Recall (Sens):  {recall:.4f}")
    print(f"F2-Score:       {f2:.4f}")
    print(f"Especificidad:  {especificidad:.4f}")
    
    return mse, y_pred

print(f"Calculando predicciones finales...")

recons_val_pre = ae_opt.predict(X_val, verbose=0)
mse_val_pre = np.mean(np.power(X_val - recons_val_pre, 2), axis=1)

# 2. Ahora sí, calculas el umbral basado en esos errores
threshold_percentil = np.percentile(mse_val_pre, mejor_config['params']['threshold_percentile'])

# 3. Llamas a tus funciones de evaluación
mse_train, y_pred_train = evaluate_set(X_train, y_train, ae_opt, threshold_percentil, "ENTRENAMIENTO (TRAIN)")
mse_val, y_pred_val = evaluate_set(X_val, y_val, ae_opt, threshold_percentil, "VALIDACIÓN (VAL)")

# Guardar resultados de validación para gráficas posteriores
error_val_df = pd.DataFrame({
    'reconstruction_error': mse_val,
    'true_class': y_val,
    'prediction': y_pred_val
})
# Out:
# Calculando predicciones finales...
#
# === EVALUACIÓN: ENTRENAMIENTO (TRAIN) ===
# Umbral utilizado: 5.8975
# Matriz de Confusión:
# [[226581    871]
#  [   233    160]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227452
#            1       0.16      0.41      0.22       393
#
#     accuracy                           1.00    227845
#    macro avg       0.58      0.70      0.61    227845
# weighted avg       1.00      1.00      1.00    227845
#
# --- Medidas de Desempeño ---
# Precisión:      0.1552
# Recall (Sens):  0.4071
# F2-Score:       0.3073
# Especificidad:  0.9962
#
# === EVALUACIÓN: VALIDACIÓN (VAL) ===
# Umbral utilizado: 5.8975
# Matriz de Confusión:
# [[56620   243]
#  [   57    42]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       0.15      0.42      0.22        99
#
#     accuracy                           0.99     56962
#    macro avg       0.57      0.71      0.61     56962
# weighted avg       1.00      0.99      1.00     56962
#
# --- Medidas de Desempeño ---
# Precisión:      0.1474
# Recall (Sens):  0.4242
# F2-Score:       0.3084
# Especificidad:  0.9957

# %%
def plot_final_results(df_error, threshold, title="Resultados de Validación"):
    plt.figure(figsize=(12, 6))
    
    # Separamos para asegurar el orden de las capas (Fraude arriba)
    normal = df_error[df_error['true_class'] == 0]
    fraude = df_error[df_error['true_class'] == 1]
    
    plt.scatter(normal.index, normal.reconstruction_error, alpha=0.5, 
                label='Normal', s=10, color='royalblue')
    plt.scatter(fraude.index, fraude.reconstruction_error, alpha=0.9, 
                label='Fraude', s=25, color='darkorange', edgecolors='white')
    
    plt.axhline(y=threshold, color='red', linestyle='--', label=f'Umbral ({threshold:.2f})')
    
    plt.title(title, fontsize=15)
    plt.ylabel("Error de Reconstrucción (MSE)")
    plt.xlabel("Índice del Dato")
    plt.legend(loc='upper right')
    plt.grid(axis='y', alpha=0.3)
    plt.show()

# Ejecutar con el DataFrame de validación que ya creaste
plot_final_results(error_val_df, threshold_percentil, "Evaluación Final: Set de Validación (No Visto)")

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

def plot_roc_curve(y_train, mse_train, y_val, mse_val):
    # 1. Calcular FPR, TPR y AUC para Train
    fpr_train, tpr_train, _ = roc_curve(y_train, mse_train)
    roc_auc_train = auc(fpr_train, tpr_train)

    # 2. Calcular FPR, TPR y AUC para Validación
    fpr_val, tpr_val, _ = roc_curve(y_val, mse_val)
    roc_auc_val = auc(fpr_val, tpr_val)

    # 3. Graficar
    plt.figure(figsize=(10, 7))
    plt.plot(fpr_train, tpr_train, color='royalblue', lw=2, 
             label=f'ROC Train (AUC = {roc_auc_train:.4f})')
    plt.plot(fpr_val, tpr_val, color='darkorange', lw=2, 
             label=f'ROC Validación (AUC = {roc_auc_val:.4f})')
    
    # Línea base (azar)
    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Tasa de Falsos Positivos (FPR)')
    plt.ylabel('Tasa de Verdaderos Positivos (Recall)')
    plt.title('Curva ROC: Entrenamiento vs Validación')
    plt.legend(loc="lower right")
    plt.grid(alpha=0.3)
    plt.show()

# Ejecutar la gráfica con los MSE que ya calculaste
plot_roc_curve(y_train, mse_train, y_val, mse_val)

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
def plot_precision_recall_curve(y_train, mse_train, y_val, mse_val):
    # 1. Calcular Precisión y Recall para varios umbrales en Train
    precision_train, recall_train, _ = precision_recall_curve(y_train, mse_train)
    ap_train = average_precision_score(y_train, mse_train)

    # 2. Calcular Precisión y Recall para varios umbrales en Validación
    precision_val, recall_val, _ = precision_recall_curve(y_val, mse_val)
    ap_val = average_precision_score(y_val, mse_val)

    # 3. Graficar
    plt.figure(figsize=(10, 7))
    plt.plot(recall_train, precision_train, color='royalblue', lw=2, 
             label=f'PRC Train (AP = {ap_train:.4f})')
    plt.plot(recall_val, precision_val, color='darkorange', lw=2, 
             label=f'PRC Validación (AP = {ap_val:.4f})')
    
    # Línea base (proporción de la clase positiva)
    baseline = sum(y_val) / len(y_val)
    plt.axhline(y=baseline, color='navy', lw=1, linestyle='--', label=f'Baseline ({baseline:.4f})')
    
    plt.xlabel('Recall (Capacidad de detección)')
    plt.ylabel('Precision (Pureza de las alertas)')
    plt.title('Curva Precision-Recall: Entrenamiento vs Validación')
    plt.legend(loc="upper right")
    plt.grid(alpha=0.3)
    plt.show()

# Ejecutar la gráfica
plot_precision_recall_curve(y_train, mse_train, y_val, mse_val)
